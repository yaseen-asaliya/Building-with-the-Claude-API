# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the main.py and summarize its content.
    """,
)

run_conversation(messages)
# Out:
# I'll open and read the main.py file for you.
# Let me try viewing the current directory:
# Now let me open the main.py file:
# ## Summary of main.py
#
# The `main.py` file is very simple and contains:
#
# - **A single function**: `greeting()`
# - **Functionality**: The function prints a welcome message: "Hello! Welcome to the Claude API tools demonstration."
#
# This appears to be a basic demonstration file, likely used as a starting point or example for working with Claude API tools. The file is minimal with just 2 lines of code defining a greeting function that outputs a welcome message when called.
# [{'role': 'user',
#   'content': '\n    Open the main.py and summarize its content.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll open and read the main.py file for you.", type='text'),
#    ToolUseBlock(id='toolu_016Wfnp2LiM53C6zsUucmjfU', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/repo'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_016Wfnp2LiM53C6zsUucmjfU',
#     'content': "Error: Access denied: Path '/repo' is outside the allowed directory",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me try viewing the current directory:', type='text'),
#    ToolUseBlock(id='toolu_01QVj3vA1hWAogHXfcdv4q3z', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01QVj3vA1hWAogHXfcdv4q3z',
#     'content': '".backups\\n.env\\n.git\\n.gitignore\\naccess_claude.ipynb\\ndata\\nmain.py\\nprompt_engineering.ipynb\\nprompt_evals.ipynb\\nREADME.md\\ntext_editor_tool.ipynb\\ntools.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Now let me open the main.py file:', type='text'),
#    ToolUseBlock(id='toolu_01TJwyznfnpwEUdLaXKKXkyL', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': 'main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01TJwyznfnpwEUdLaXKKXkyL',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello! Welcome to the Claude API tools demonstration.\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='## Summary of main.py\n\nThe `main.py` file is very simple and contains:\n\n- **A single function**: `greeting()`\n- **Functionality**: The function prints a welcome message: "Hello! Welcome to the Claude API tools demonstration."\n\nThis appears to be a basic demonstration file, likely used as a starting point or example for working with Claude API tools. The file is minimal with just 2 lines of code defining a greeting function that outputs a welcome message when called.', type='text')]}]

# %%
messages = []

add_user_message(
    messages,
    """
    Open the main.py and write out a function to calcualte pi to the 5th digit.

    and create ./test.py to test your implementation of the pi function.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit in main.py and create a test file for it.
#
# Great! I can see that main.py already has a function to calculate pi to the 5th digit. Now let me create a test.py file to test this implementation:
# Perfect! I've created the test.py file. Let me provide a summary of what I found and created:
#
# ## Summary
#
# **main.py** - Already contains a function `calculate_pi_to_5th_digit()` that:
# - Uses the Leibniz formula to calculate pi (π/4 = 1 - 1/3 + 1/5 - 1/7 + ...)
# - Runs 500,000 iterations to ensure accuracy to 5 decimal places
# - Returns pi rounded to 5 decimal places: **3.14159**
#
# **test.py** - Created a comprehensive test file that:
# - Imports the `calculate_pi_to_5th_digit` function from main.py
# - Tests the calculated value against the expected value (3.14159)
# - Compares with Python's built-in `math.pi` rounded to 5 decimal places
# - Verifies the return type is a float
# - Provides clear test output with pass/fail indicators
#
# To run the tests, simply execute:
# ```bash
# python test.py
# ```
#
# The test will display the calculated pi value, compare it with the expected value, and show whether all tests passed!
# [{'role': 'user',
#   'content': '\n    Open the main.py and write out a function to calcualte pi to the 5th digit.\n\n    and create ./test.py to test your implementation of the pi function.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit in main.py and create a test file for it.", type='text'),
#    ToolUseBlock(id='toolu_01KNCsxeEeD9fRtJLZzFZXHW', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01KNCsxeEeD9fRtJLZzFZXHW',
#     'content': '".backups\\n.env\\n.git\\n.gitignore\\naccess_claude.ipynb\\ndata\\nmain.py\\nprompt_engineering.ipynb\\nprompt_evals.ipynb\\nREADME.md\\ntext_editor_tool.ipynb\\ntools.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_0142d4LRvJDjciGQyWYxEBSU', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': 'main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_0142d4LRvJDjciGQyWYxEBSU',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello! Welcome to the Claude API tools demonstration.\\")\\n3: \\n4: def calculate_pi_to_5th_digit():\\n5:     \\"\\"\\"\\n6:     Calculate pi to the 5th decimal digit using the Leibniz formula.\\n7:     Returns pi as 3.14159\\n8:     \\"\\"\\"\\n9:     # Using Leibniz formula: pi/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\\n10:     # We need enough iterations for 5 decimal places accuracy\\n11:     pi_over_4 = 0\\n12:     iterations = 500000  # Enough iterations for 5 decimal places\\n13:     \\n14:     for i in range(iterations):\\n15:         pi_over_4 += ((-1) ** i) / (2 * i + 1)\\n16:     \\n17:     pi = 4 * pi_over_4\\n18:     \\n19:     # Round to 5 decimal places\\n20:     pi_rounded = round(pi, 5)\\n21:     \\n22:     return pi_rounded"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Great! I can see that main.py already has a function to calculate pi to the 5th digit. Now let me create a test.py file to test this implementation:', type='text'),
#    ToolUseBlock(id='toolu_01VuJ3rzfibZQ88LUink7nZz', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': '"""\nTest file for the pi calculation function in main.py\n"""\nimport math\nfrom main import calculate_pi_to_5th_digit\n\n\ndef test_pi_calculation():\n    """\n    Test the calculate_pi_to_5th_digit function\n    """\n    # Get the calculated pi value\n    calculated_pi = calculate_pi_to_5th_digit()\n    \n    # Expected value of pi to 5 decimal places\n    expected_pi = 3.14159\n    \n    # Also compare with Python\'s math.pi rounded to 5 decimal places\n    math_pi_rounded = round(math.pi, 5)\n    \n    print("=" * 50)\n    print("Pi Calculation Test Results")\n    print("=" * 50)\n    print(f"Calculated Pi:        {calculated_pi}")\n    print(f"Expected Pi:          {expected_pi}")\n    print(f"Python\'s math.pi:     {math.pi}")\n    print(f"math.pi (rounded):    {math_pi_rounded}")\n    print("=" * 50)\n    \n    # Check if the calculated value matches expected\n    if calculated_pi == expected_pi:\n        print("✓ TEST PASSED: Calculated pi matches expected value!")\n    else:\n        print(f"✗ TEST FAILED: Expected {expected_pi}, got {calculated_pi}")\n    \n    # Check if it matches Python\'s math.pi (rounded)\n    if calculated_pi == math_pi_rounded:\n        print("✓ TEST PASSED: Calculated pi matches math.pi (rounded to 5 digits)!")\n    else:\n        print(f"✗ TEST FAILED: math.pi rounded is {math_pi_rounded}, got {calculated_pi}")\n    \n    # Check the type\n    if isinstance(calculated_pi, float):\n        print("✓ TEST PASSED: Return type is float")\n    else:\n        print(f"✗ TEST FAILED: Expected float, got {type(calculated_pi)}")\n    \n    print("=" * 50)\n    \n    return calculated_pi == expected_pi and calculated_pi == math_pi_rounded\n\n\nif __name__ == "__main__":\n    print("\\nRunning pi calculation tests...\\n")\n    success = test_pi_calculation()\n    \n    if success:\n        print("\\n🎉 All tests passed successfully!")\n    else:\n        print("\\n⚠️  Some tests failed. Please review the results above.")\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01VuJ3rzfibZQ88LUink7nZz',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've created the test.py file. Let me provide a summary of what I found and created:\n\n## Summary\n\n**main.py** - Already contains a function `calculate_pi_to_5th_digit()` that:\n- Uses the Leibniz formula to calculate pi (π/4 = 1 - 1/3 + 1/5 - 1/7 + ...)\n- Runs 500,000 iterations to ensure accuracy to 5 decimal places\n- Returns pi rounded to 5 decimal places: **3.14159**\n\n**test.py** - Created a comprehensive test file that:\n- Imports the `calculate_pi_to_5th_digit` function from main.py\n- Tests the calculated value against the expected value (3.14159)\n- Compares with Python's built-in `math.pi` rounded to 5 decimal places\n- Verifies the return type is a float\n- Provides clear test output with pass/fail indicators\n\nTo run the tests, simply execute:\n```bash\npython test.py\n```\n\nThe test will display the calculated pi value, compare it with the expected value, and show whether all tests passed!", type='text')]}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
